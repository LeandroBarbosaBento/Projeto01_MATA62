# %%
import pandas as pd
import matplotlib as mp
import matplotlib.pyplot as plt

# %% [markdown]
# # Carregar arquivos
# + leitura de arquivos no programa e concatenação dos arquivos mensais em dataframes com dados anuais

# %%
#LEITURA DOS DADOS DE 2015 EM UM ÚNICO DATASET
lista = []
caminho = '2015/2015_{}.csv'
for i in range(1,13):
    lista.append(pd.read_csv(caminho.format(i)))
    
dados2015 = pd.concat(lista)
dados2015.columns = ['SiglaDaEmpresa', 'NúmeroDoVoo', 'DI', 'TipoDeLinha', 'AeroportoOrigem', 'AeroportoDestino', 'PartidaPrevista', 'PartidaReal', 'ChegadaPrevista', 'ChegadaReal', 'Situacao', 'Justificativa', 'mes']

#Exibir informações do dataset
#print(dados2015.shape)
#print(dados2015.columns)
#dados2015.head()
# Out:
# /home/leandro/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (2) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
#LEITURA DOS DADOS DE 2016 EM UM ÚNICO DATASET
lista.clear()
caminho = '2016/2016_{}.csv'
for i in range(1,13):
    lista.append(pd.read_csv(caminho.format(i)))
    
dados2016 = pd.concat(lista)
dados2016.columns = ['SiglaDaEmpresa', 'NúmeroDoVoo', 'DI', 'TipoDeLinha', 'AeroportoOrigem', 'AeroportoDestino', 'PartidaPrevista', 'PartidaReal', 'ChegadaPrevista', 'ChegadaReal', 'Situacao', 'Justificativa', 'mes']

# %%
#LEITURA DOS DADOS DE 2017 EM UM ÚNICO DATASET
lista.clear()
caminho = '2017/2017_{}.csv'
for i in range(1,13):
    lista.append(pd.read_csv(caminho.format(i)))
    
dados2017 = pd.concat(lista)
dados2017.columns = ['SiglaDaEmpresa', 'NúmeroDoVoo', 'DI', 'TipoDeLinha', 'AeroportoOrigem', 'AeroportoDestino', 'PartidaPrevista', 'PartidaReal', 'ChegadaPrevista', 'ChegadaReal', 'Situacao', 'Justificativa', 'mes']

# %%
#LEITURA DOS DADOS DE 2018 EM UM ÚNICO DATASET
lista.clear()
caminho = '2018/2018_{}.csv'
for i in range(1,13):
    lista.append(pd.read_csv(caminho.format(i)))
    
dados2018 = pd.concat(lista)
dados2018.columns = ['SiglaDaEmpresa', 'NúmeroDoVoo', 'DI', 'TipoDeLinha', 'AeroportoOrigem', 'AeroportoDestino', 'PartidaPrevista', 'PartidaReal', 'ChegadaPrevista', 'ChegadaReal', 'Situacao', 'Justificativa', 'mes']

# %%
#LEITURA DOS DADOS DE 2019 EM UM ÚNICO DATASET
lista.clear()
caminho = '2019/2019_{}.csv'
for i in range(1,13):
    lista.append(pd.read_csv(caminho.format(i)))
    
dados2019 = pd.concat(lista)
dados2019.columns = ['SiglaDaEmpresa', 'NúmeroDoVoo', 'DI', 'TipoDeLinha', 'AeroportoOrigem', 'AeroportoDestino', 'PartidaPrevista', 'PartidaReal', 'ChegadaPrevista', 'ChegadaReal', 'Situacao', 'Justificativa', 'mes']

# %% [markdown]
# # Visualizar se os dataframes foram carregados de maneira correta
# + 5 primeiras linhas de cada um deles

# %%
dados2015.head()

# %%
dados2016.head()

# %%
dados2017.head()

# %%
dados2018.head()

# %%
dados2019.head()

# %% [markdown]
# # Criação de gráficos para gerar a dashboard

# %%
#Histograma: quantidade de voos por empresa

#Observar tamanho da figura para que apareçam de maneira mais legível os nomes das empresas
#Talvez retirar algumas das empresas que fizeram menor número de voos para melhorar a visualização
dados2015['SiglaDaEmpresa'].hist(bins = 82 , figsize = (35, 12))

# %% [markdown]
# # Geração de gráficos para análise da quantidade de voos ao longo do ano

# %%
#Selecionar dataset com colunas de empresas e meses do ano de 2015
dados2015PorMes = dados2015.filter(items = ['SiglaDaEmpresa', 'mes'], axis = 1).groupby('mes').count()

# %%
#Adicionar coluna com números referentes ao mês
#Facilita na ordenação
dados2015PorMes['mesNumero'] = [4, 8, 12, 2, 1, 7, 6, 5, 3, 11, 10, 9]

# %%
#Ordenar o dataframe
dados2015PorMes = dados2015PorMes.sort_values(by = "mesNumero", ascending = True)

# %%
fig, ax = plt.subplots(5,2)

fig.subplots_adjust(wspace = 0.5)

#/* *****VOOS DE 2015***** */


#Criar gráfico de barras para a quantidade de voos por mês
ax1 = dados2015PorMes.plot.bar(figsize = (15,5),ax = ax[0,0])
ax1.set_title('Variação dos voos em 2015 ao longo dos meses')
ax1.legend(labels = ['Voos'])

aux2015 = dados2015PorMes

#Gerar gráfico de linha com a variação na quantidade de voos no ano de 2015
ax2 = aux2015.drop(columns = ["mesNumero"]).plot(ax = ax[0,1])
ax2.set_title('Variação dos voos em 2015 ao longo dos meses')
ax2.legend(labels = ['Voos'])

aux2015 = dados2015PorMes


#/* *****VOOS DE 2016***** */


#Selecionar dataset com colunas de empresas e meses do ano de 2016
dados2016PorMes = dados2016.filter(items = ['SiglaDaEmpresa', 'mes'], axis = 1).groupby('mes').count()

#Adicionar coluna com números referentes ao mês
#Facilita na ordenação
dados2016PorMes['mesNumero'] = [4, 8, 12, 2, 1, 7, 6, 5, 3, 11, 10, 9]

dados2016PorMes = dados2016PorMes.sort_values(by = "mesNumero", ascending = True)

#Criar gráfico de barras para a quantidade de voos por mês
ax3 = dados2016PorMes.plot.bar(figsize = (15,5),ax = ax[1,0])
ax3.set_title('Variação dos voos em 2016 ao longo dos meses')
ax3.legend(labels = ['Voos'])

aux2016 = dados2016PorMes

#Gerar gráfico de linha com a variação na quantidade de voos no ano de 2016
ax4 = aux2016.drop(columns = ["mesNumero"]).plot(ax = ax[1,1])
ax4.set_title('Variação dos voos em 2016 ao longo dos meses')
ax4.legend(labels = ['Voos'])

#/* *****VOOS DE 2017***** */

dados2017PorMes = dados2017.filter(items = ['SiglaDaEmpresa', 'mes'], axis = 1).groupby('mes').count()

#Adicionar coluna com números referentes ao mês
#Facilita na ordenação
dados2017PorMes['mesNumero'] = [4, 8, 12, 2, 1, 7, 6, 5, 3, 11, 10, 9]

dados2017PorMes = dados2017PorMes.sort_values(by = "mesNumero", ascending = True)

#Criar gráfico de barras para a quantidade de voos por mês
ax5 = dados2017PorMes.plot.bar(figsize = (15,5),ax = ax[2,0])
ax5.legend(labels = ['Voos'])
ax5.set_title('Variação dos voos em 2017 ao longo dos meses')
aux2017 = dados2017PorMes

#Gerar gráfico de linha com a variação na quantidade de voos no ano de 2016
ax6 = aux2017.drop(columns = ["mesNumero"]).plot(ax = ax[2,1])
ax6.set_title('Variação dos voos em 2017 ao longo dos meses')
ax6.legend(labels = ['Voos'])

#/* *****VOOS DE 2018***** */

dados2018PorMes = dados2018.filter(items = ['SiglaDaEmpresa', 'mes'], axis = 1).groupby('mes').count()

#Adicionar coluna com números referentes ao mês
#Facilita na ordenação
dados2018PorMes['mesNumero'] = [4, 8, 12, 2, 1, 7, 6, 5, 3, 11, 10, 9]

dados2018PorMes = dados2018PorMes.sort_values(by = "mesNumero", ascending = True)

#Criar gráfico de barras para a quantidade de voos por mês
ax7 = dados2018PorMes.plot.bar(figsize = (15,5),ax = ax[3,0])
ax7.legend(labels = ['Voos'])
ax7.set_title('Variação dos voos em 2018 ao longo dos meses')
aux2018 = dados2018PorMes

#Gerar gráfico de linha com a variação na quantidade de voos no ano de 2016
ax8 = aux2018.drop(columns = ["mesNumero"]).plot(ax = ax[3,1])
ax8.set_title('Variação dos voos em 2018 ao longo dos meses')
ax8.legend(labels = ['Voos'])

#/* *****VOOS DE 2019***** */

dados2019PorMes = dados2019.filter(items = ['SiglaDaEmpresa', 'mes'], axis = 1).groupby('mes').count()

#Adicionar coluna com números referentes ao mês
#Facilita na ordenação
dados2019PorMes['mesNumero'] = [4, 8, 12, 2, 1, 7, 6, 5, 3, 11, 10, 9]

dados2019PorMes = dados2019PorMes.sort_values(by = "mesNumero", ascending = True)

#Criar gráfico de barras para a quantidade de voos por mês
ax9 = dados2019PorMes.plot.bar(figsize = (15,5),ax = ax[4,0])
ax9.legend(labels = ['Voos'])
ax9.set_title('Variação dos voos em 2019 ao longo dos meses')
aux2019 = dados2019PorMes

#Gerar gráfico de linha com a variação na quantidade de voos no ano de 2016
ax10 = aux2019.drop(columns = ["mesNumero"]).plot(ax = ax[4,1])
ax10.set_title('Variação dos voos em 2019 ao longo dos meses')
ax10.legend(labels = ['Voos'])

# %%
#Exibir gráficos de análise dos voos ao longo dos meses em todos os anos

fig.tight_layout(pad = 0.8)
fig.set_size_inches(13,15)
fig

# %%
#Selecionar dataset com colunas de empresas e meses do ano de 2016
dados2016PorMes = dados2016.filter(items = ['SiglaDaEmpresa', 'mes'], axis = 1).groupby('mes').count()

# %%
#Adicionar coluna com números referentes ao mês
#Facilita na ordenação
dados2016PorMes['mesNumero'] = [4, 8, 12, 2, 1, 7, 6, 5, 3, 11, 10, 9]

# %%
dados2016PorMes = dados2016PorMes.sort_values(by = "mesNumero", ascending = True)

# %%
#Importar numpy para utilizar a função np.where() para adicionar a coluna atrasou ou não atrasou ao dataset.
import numpy as np

# %%
#Adicionar coluna informando se o voo atrasou ou não
#Voos cancelados aparecem como atrasados -> como mudar?
dados2015["Atrasou"] = np.where(dados2015['PartidaPrevista'] >= dados2015['PartidaReal'],0,1)
dados2016["Atrasou"] = np.where(dados2016['PartidaPrevista'] >= dados2016['PartidaReal'],0,1)
dados2017["Atrasou"] = np.where(dados2017['PartidaPrevista'] >= dados2017['PartidaReal'],0,1)
dados2018["Atrasou"] = np.where(dados2018['PartidaPrevista'] >= dados2018['PartidaReal'],0,1)
dados2019["Atrasou"] = np.where(dados2019['PartidaPrevista'] >= dados2019['PartidaReal'],0,1)

# %%
#Selecionar dados em dataset apenas com coluna de nome da empresa e informação de atraso. 
dadosSelecionados2015 = dados2015.filter(items = ['SiglaDaEmpresa', 'Atrasou'])
dadosSelecionados2015.columns = ['Voos', 'Situacao']

#Remover os NaN do conjunto de dados
dadosSelecionados2015 = dadosSelecionados2015.dropna()

#Armazena os dados de empresas atrasadas em um dataframe
empresasAtrasos2015 = dadosSelecionados2015[dadosSelecionados2015.Situacao == 1]

# %%
dadosSelecionados2016 = dados2016.filter(items = ['SiglaDaEmpresa', 'Atrasou'])
dadosSelecionados2016.columns = ['Voos', 'Situacao']
dadosSelecionados2016 = dadosSelecionados2016.dropna()
empresasAtrasos2016 = dadosSelecionados2016[dadosSelecionados2016.Situacao == 1]
empresasAtrasos2016.shape
# Out:
# (275150, 2)

# %%
dadosSelecionados2017 = dados2017.filter(items = ['SiglaDaEmpresa', 'Atrasou'])
dadosSelecionados2017.columns = ['Voos', 'Situacao']
dadosSelecionados2017 = dadosSelecionados2017.dropna()
empresasAtrasos2017 = dadosSelecionados2017[dadosSelecionados2017.Situacao == 1]
empresasAtrasos2017.shape
# Out:
# (345470, 2)

# %%
dadosSelecionados2018 = dados2018.filter(items = ['SiglaDaEmpresa', 'Atrasou'])
dadosSelecionados2018.columns = ['Voos', 'Situacao']
dadosSelecionados2018 = dadosSelecionados2018.dropna()
empresasAtrasos2018 = dadosSelecionados2018[dadosSelecionados2018.Situacao == 1]
empresasAtrasos2018.shape
# Out:
# (350490, 2)

# %%
dadosSelecionados2019 = dados2019.filter(items = ['SiglaDaEmpresa', 'Atrasou'])
dadosSelecionados2019.columns = ['Voos', 'Situacao']
dadosSelecionados2019 = dadosSelecionados2019.dropna()

empresasAtrasos2019 = dadosSelecionados2019[dadosSelecionados2019.Situacao == 1]
empresasAtrasos2019.shape
# Out:
# (307701, 2)

# %%
voosAtrasados = pd.concat([empresasAtrasos2015, empresasAtrasos2016,\
                        empresasAtrasos2017, empresasAtrasos2018, empresasAtrasos2019])

# %%
voosAtrasados.shape
# Out:
# (1573313, 2)

# %%
#Salva em um dataframe as 10 empresas mais atrasadas ao longo desses 5 anos
empresasMaisAtrasadas = voosAtrasados.groupby("Voos").count().sort_values(by = "Situacao", ascending = False).head(10)

# %%
empresasMaisAtrasadas
# Out:
#       Situacao
# Voos
# GLO     442859
# AZU     433608
# TAM     354244
# ONE      86164
# PTB      40789
# LTG      23332
# LCO      18633
# LAE      13360
# TTL      11563
# TPA       9265

# %%
#Gráfico com a relação das 10 empresas que mais atrasam voos

empresasMaisAtrasadas.plot.bar()

# %% [markdown]
# # Quantidade de voos que atrasaram e não atrasaram

# %%
#Quantidade de dados que atrasaram e não atrasaram
AtrasouOuNao = dadosSelecionados.groupby("Situacao").count().sort_values(by = "Voos", ascending = False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-dda7fb34c66a> in <module>
#       1 #Quantidade de dados que atrasaram e não atrasaram
# ----> 2 AtrasouOuNao = dadosSelecionados.groupby("Situacao").count().sort_values(by = "Voos", ascending = False)
#
# NameError: name 'dadosSelecionados' is not defined

# %%
AtrasouOuNao.index = ['Atrasou', 'Não atrasou']

# %%
AtrasouOuNao.head()

# %%
AtrasouOuNao.plot.bar()

# %%
dados2015.columns

# %%
dadosSelecionados.head()
